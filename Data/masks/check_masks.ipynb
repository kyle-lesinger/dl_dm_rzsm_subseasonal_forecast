# %%
import xarray as xr
import matplotlib as plt

# %%
a=xr.open_dataset('CONUS_mask.nc4')

# %%
a['NCA-LDAS_mask'].plot()

# %%
b=a.isel(S=0)

# %%
c=b.drop_vars('S')

# %%
c.to_netcdf('test.nc4')

# %%
b.drop_dims('S')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /glade/derecho/scratch/klesinger/tmp/ipykernel_21108/3920120039.py in ?()
# ----> 1 b.drop_dims('S')
#
# /glade/work/klesinger/conda-envs/tf212gpu_new/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, drop_dims, errors)
#    6254
#    6255         if errors == "raise":
#    6256             missing_dims = drop_dims - set(self.dims)
#    6257             if missing_dims:
# -> 6258                 raise ValueError(
#    6259                     f"Dimensions {tuple(missing_dims)} not found in data dimensions {tuple(self.dims)}"
#    6260                 )
#    6261
#
# ValueError: Dimensions ('S',) not found in data dimensions ('X', 'Y')
